# %%
import twitter
import pandas as pd

# %%
# VARIABLES
BEARER_TOKEN = 'AAAAAAAAAAAAAAAAAAAAAI0YKQEAAAAAx7jZyYaOEmZo9rLnU%2BJ8NB%2FzM%2FA%3DSHlLkhfQLPc1ElDA60Uf2y2Ohl5rFNPYJJg3yXCj2UIX1LZ5SC'

# %%
t_h = twitter.Twitter(
    auth=twitter.OAuth2(bearer_token=BEARER_TOKEN)
    )

# %%
# Discovery. Example: we are searching for tweets revolving the new Korean TV series _Squid Game_.
query = t_h.search.tweets(q='Squid game', lang='en', count=100)
query_2 = t_h.search.tweets(q='Squid game', lang='en', count=100, max_id='1452215497487966219')

# %%
squid_df = pd.DataFrame(query['statuses'])
squid_df.head()
# Out:
#                        created_at                   id               id_str  \
# 0  Sun Oct 24 11:43:55 +0000 2021  1452239427514818567  1452239427514818567
# 1  Sun Oct 24 11:43:52 +0000 2021  1452239413749092355  1452239413749092355
# 2  Sun Oct 24 11:43:51 +0000 2021  1452239409282174981  1452239409282174981
# 3  Sun Oct 24 11:43:47 +0000 2021  1452239395134836754  1452239395134836754
# 4  Sun Oct 24 11:43:46 +0000 2021  1452239390584066056  1452239390584066056
#
#                                                 text  truncated  \
# 0  Squid Games 2 Game#1 😂😂\n#SquidGames #T20World...      False
# 1  RT @thehermeister: Us 🤝 Squid Game\n\nHallowee...      False
# 2  I can only interpret the existence of Squid Ga...      False
# 3  the funniest response to squid game i keep see...       True
# 4  RT @FarraNazira: Squid Game ❎\nGintama ✅ https...      False
#
#                                             entities  \
# 0  {'hashtags': [{'text': 'SquidGames', 'indices'...
# 1  {'hashtags': [], 'symbols': [], 'user_mentions...
# 2  {'hashtags': [], 'symbols': [], 'user_mentions...
# 3  {'hashtags': [], 'symbols': [], 'user_mentions...
# 4  {'hashtags': [], 'symbols': [], 'user_mentions...
#
#                                    extended_entities  \
# 0  {'media': [{'id': 1452239170215219202, 'id_str...
# 1  {'media': [{'id': 1452191309926735878, 'id_str...
# 2                                                NaN
# 3                                                NaN
# 4  {'media': [{'id': 1451617062229458947, 'id_str...
#
#                                             metadata  \
# 0  {'iso_language_code': 'en', 'result_type': 're...
# 1  {'iso_language_code': 'en', 'result_type': 're...
# 2  {'iso_language_code': 'en', 'result_type': 're...
# 3  {'iso_language_code': 'en', 'result_type': 're...
# 4  {'iso_language_code': 'en', 'result_type': 're...
#
#                                               source  in_reply_to_status_id  \
# 0  <a href="https://mobile.twitter.com" rel="nofo...                    NaN
# 1  <a href="http://twitter.com/download/iphone" r...                    NaN
# 2  <a href="https://about.twitter.com/products/tw...                    NaN
# 3  <a href="https://about.twitter.com/products/tw...                    NaN
# 4  <a href="http://twitter.com/download/android" ...                    NaN
#
#    ... retweet_count  favorite_count favorited retweeted possibly_sensitive  \
# 0  ...             0               0     False     False              False
# 1  ...             5               0     False     False              False
# 2  ...             0               0     False     False                NaN
# 3  ...             0               1     False     False                NaN
# 4  ...         11973               0     False     False              False
#
#   lang                                   retweeted_status quoted_status_id  \
# 0   en                                                NaN              NaN
# 1   en  {'created_at': 'Sun Oct 24 08:32:44 +0000 2021...              NaN
# 2   en                                                NaN              NaN
# 3   en                                                NaN              NaN
# 4   en  {'created_at': 'Fri Oct 22 18:35:21 +0000 2021...              NaN
#
#   quoted_status_id_str  quoted_status
# 0                  NaN            NaN
# 1                  NaN            NaN
# 2                  NaN            NaN
# 3                  NaN            NaN
# 4                  NaN            NaN
#
# [5 rows x 30 columns]

# %% [markdown]
# From here we can see that we only need their tweets. Therefore we only take the 'text'.

# %%
# Appending
squid_df.append(pd.DataFrame(query_2['statuses'])).reset_index().drop('index', axis=1)
# squid_df = squid_df.append(pd.DataFrame(query_2['statuses']).get('text'))
# squid_tweets = squid_tweets.reset_index().drop('index')
# squid_tweets.tail()
# Out:
#                          created_at                   id               id_str  \
# 0    Sun Oct 24 11:43:55 +0000 2021  1452239427514818567  1452239427514818567
# 1    Sun Oct 24 11:43:52 +0000 2021  1452239413749092355  1452239413749092355
# 2    Sun Oct 24 11:43:51 +0000 2021  1452239409282174981  1452239409282174981
# 3    Sun Oct 24 11:43:47 +0000 2021  1452239395134836754  1452239395134836754
# 4    Sun Oct 24 11:43:46 +0000 2021  1452239390584066056  1452239390584066056
# ..                              ...                  ...                  ...
# 195  Sun Oct 24 10:05:37 +0000 2021  1452214689426034692  1452214689426034692
# 196  Sun Oct 24 10:05:33 +0000 2021  1452214673147928584  1452214673147928584
# 197  Sun Oct 24 10:05:31 +0000 2021  1452214662578286600  1452214662578286600
# 198  Sun Oct 24 10:05:23 +0000 2021  1452214632844873728  1452214632844873728
# 199  Sun Oct 24 10:05:22 +0000 2021  1452214627488702471  1452214627488702471
#
#                                                   text  truncated  \
# 0    Squid Games 2 Game#1 😂😂\n#SquidGames #T20World...      False
# 1    RT @thehermeister: Us 🤝 Squid Game\n\nHallowee...      False
# 2    I can only interpret the existence of Squid Ga...      False
# 3    the funniest response to squid game i keep see...       True
# 4    RT @FarraNazira: Squid Game ❎\nGintama ✅ https...      False
# ..                                                 ...        ...
# 195  the invitation to my wedding is squid game inv...      False
# 196  RT @MrMichaelSpicer: squid game deleted scene ...      False
# 197  RT @FarraNazira: Squid Game ❎\nGintama ✅ https...      False
# 198  Cignature Squid Game Version 😝🤣 \nHow's it??\n...       True
# 199  RT @DlSEAZE: when the squid game challenge is ...      False
#
#                                               entities  \
# 0    {'hashtags': [{'text': 'SquidGames', 'indices'...
# 1    {'hashtags': [], 'symbols': [], 'user_mentions...
# 2    {'hashtags': [], 'symbols': [], 'user_mentions...
# 3    {'hashtags': [], 'symbols': [], 'user_mentions...
# 4    {'hashtags': [], 'symbols': [], 'user_mentions...
# ..                                                 ...
# 195  {'hashtags': [], 'symbols': [], 'user_mentions...
# 196  {'hashtags': [], 'symbols': [], 'user_mentions...
# 197  {'hashtags': [], 'symbols': [], 'user_mentions...
# 198  {'hashtags': [{'text': 'cignature', 'indices':...
# 199  {'hashtags': [], 'symbols': [], 'user_mentions...
#
#                                      extended_entities  \
# 0    {'media': [{'id': 1452239170215219202, 'id_str...
# 1    {'media': [{'id': 1452191309926735878, 'id_str...
# 2                                                  NaN
# 3                                                  NaN
# 4    {'media': [{'id': 1451617062229458947, 'id_str...
# ..                                                 ...
# 195  {'media': [{'id': 1452214681091858441, 'id_str...
# 196  {'media': [{'id': 1451849297616572416, 'id_str...
# 197  {'media': [{'id': 1451617062229458947, 'id_str...
# 198                                                NaN
# 199                                                NaN
#
#                                               metadata  \
# 0    {'iso_language_code': 'en', 'result_type': 're...
# 1    {'iso_language_code': 'en', 'result_type': 're...
# 2    {'iso_language_code': 'en', 'result_type': 're...
# 3    {'iso_language_code': 'en', 'result_type': 're...
# 4    {'iso_language_code': 'en', 'result_type': 're...
# ..                                                 ...
# 195  {'iso_language_code': 'en', 'result_type': 're...
# 196  {'iso_language_code': 'en', 'result_type': 're...
# 197  {'iso_language_code': 'en', 'result_type': 're...
# 198  {'iso_language_code': 'en', 'result_type': 're...
# 199  {'iso_language_code': 'en', 'result_type': 're...
#
#                                                 source  in_reply_to_status_id  \
# 0    <a href="https://mobile.twitter.com" rel="nofo...                    NaN
# 1    <a href="http://twitter.com/download/iphone" r...                    NaN
# 2    <a href="https://about.twitter.com/products/tw...                    NaN
# 3    <a href="https://about.twitter.com/products/tw...                    NaN
# 4    <a href="http://twitter.com/download/android" ...                    NaN
# ..                                                 ...                    ...
# 195  <a href="http://twitter.com/download/iphone" r...                    NaN
# 196  <a href="http://twitter.com/download/iphone" r...                    NaN
# 197  <a href="http://twitter.com/download/iphone" r...                    NaN
# 198  <a href="http://twitter.com/download/android" ...                    NaN
# 199  <a href="http://itunes.apple.com/us/app/twitte...                    NaN
#
#      ... retweet_count  favorite_count favorited retweeted possibly_sensitive  \
# 0    ...             0               0     False     False              False
# 1    ...             5               0     False     False              False
# 2    ...             0               0     False     False                NaN
# 3    ...             0               1     False     False                NaN
# 4    ...         11973               0     False     False              False
# ..   ...           ...             ...       ...       ...                ...
# 195  ...             0               0     False     False              False
# 196  ...           461               0     False     False              False
# 197  ...         11973               0     False     False              False
# 198  ...             5               6     False     False              False
# 199  ...             5               0     False     False                NaN
#
#     lang                                   retweeted_status quoted_status_id  \
# 0     en                                                NaN              NaN
# 1     en  {'created_at': 'Sun Oct 24 08:32:44 +0000 2021...              NaN
# 2     en                                                NaN              NaN
# 3     en                                                NaN              NaN
# 4     en  {'created_at': 'Fri Oct 22 18:35:21 +0000 2021...              NaN
# ..   ...                                                ...              ...
# 195   en                                                NaN              NaN
# 196   en  {'created_at': 'Sat Oct 23 09:55:32 +0000 2021...              NaN
# 197   en  {'created_at': 'Fri Oct 22 18:35:21 +0000 2021...              NaN
# 198   en                                                NaN              NaN
# 199   en  {'created_at': 'Sun Oct 24 10:04:48 +0000 2021...              NaN
#
#     quoted_status_id_str  quoted_status
# 0                    NaN            NaN
# 1                    NaN            NaN
# 2                    NaN            NaN
# 3                    NaN            NaN
# 4                    NaN            NaN
# ..                   ...            ...
# 195                  NaN            NaN
# 196                  NaN            NaN
# 197                  NaN            NaN
# 198                  NaN            NaN
# 199                  NaN            NaN
#
# [200 rows x 30 columns]

# %%
import json
json_query = json.dumps(query)

# %%
with open('squid_tweets.txt', 'w') as buffer:
    buffer.write(json_query)

# %%
# iterations following the original tweets

with open('squid_tweets_2.txt', 'w') as buffer:
    buffer.write(json.dumps(query_2))

# %%
import re

next_res = '?max_id=1452214632844873727&q=Squid%20game&lang=en&count=100&include_entities=1'
match = re.search(r'max_id=(.+)&q', next_res)
print(match.group(1))
